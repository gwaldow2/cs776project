# %%
#library(PROPER)
library(limma)
library(Seurat)
library(ggplot2)
library(Matrix)
library(rhdf5)
library(sva)
library(matrixStats)
#library(qvalue)
#library(fdrtool)
#library(DSS)
#library(DESeq2) 
source("limma-voom.R")

get_categories <- function(meta) {
    names = meta$codes
    for (i in 1:length(meta$categories)) {
        name = meta$categories[i]
        names[meta$codes==(i-1)] = name
    }
    return(names)
}

# %%
# remember to change to your own data path
file_path = "/storage10/shuchen/JerberData/alltime_fiaj_12100_5000.mtx"
meta_path = "/storage10/shuchen/JerberData/alltime_fiaj_12100_5000.h5"
h5ls(meta_path)
# Out:
#    group             name             otype       dclass  dim
# 0  /                 X                H5I_GROUP
# 1  /X                data             H5I_DATASET FLOAT   10938528
# 2  /X                indices          H5I_DATASET INTEGER 10938528
# 3  /X                indptr           H5I_DATASET INTEGER 12101
# 4  /                 layers           H5I_GROUP
# 5  /                 obs              H5I_GROUP
# 6  /obs              celltype         H5I_GROUP
# 7  /obs/celltype     categories       H5I_DATASET STRING  11
# 8  /obs/celltype     codes            H5I_DATASET INTEGER 12100
# 9  /obs              cluster_id       H5I_DATASET INTEGER 12100
# 10 /obs              donor_id         H5I_GROUP
# 11 /obs/donor_id     categories       H5I_DATASET STRING  1
# 12 /obs/donor_id     codes            H5I_DATASET INTEGER 12100
# 13 /obs              index            H5I_DATASET STRING  12100
# 14 /obs              pool_id          H5I_GROUP
# 15 /obs/pool_id      categories       H5I_DATASET STRING  2
# 16 /obs/pool_id      codes            H5I_DATASET INTEGER 12100
# 17 /obs              sample_id        H5I_GROUP
# 18 /obs/sample_id    categories       H5I_DATASET STRING  30
# 19 /obs/sample_id    codes            H5I_DATASET INTEGER 12100
# 20 /obs              sample_index     H5I_GROUP
# 21 /obs/sample_index categories       H5I_DATASET STRING  30
# 22 /obs/sample_index codes            H5I_DATASET INTEGER 12100
# 23 /obs              time_point       H5I_GROUP
# 24 /obs/time_point   categories       H5I_DATASET STRING  3
# 25 /obs/time_point   codes            H5I_DATASET INTEGER 12100
# 26 /obs              treatment        H5I_GROUP
# 27 /obs/treatment    categories       H5I_DATASET STRING  2
# 28 /obs/treatment    codes            H5I_DATASET INTEGER 12100
# 29 /                 obsm             H5I_GROUP
# 30 /obsm             X_umap           H5I_DATASET FLOAT   2 x 12100
# 31 /                 obsp             H5I_GROUP
# 32 /                 uns              H5I_GROUP
# 33 /uns              hvg              H5I_GROUP
# 34 /uns/hvg          flavor           H5I_DATASET STRING  ( 0 )
# 35 /uns              log1p            H5I_GROUP
# 36 /                 var              H5I_GROUP
# 37 /var              dispersions      H5I_DATASET FLOAT   5000
# 38 /var              dispersions_norm H5I_DATASET FLOAT   5000
# 39 /var              highly_variable  H5I_DATASET ENUM    5000
# 40 /var              index            H5I_DATASET STRING  5000
# 41 /var              means            H5I_DATASET FLOAT   5000
# 42 /var              n_cells          H5I_DATASET INTEGER 5000
# 43 /                 varm             H5I_GROUP
# 44 /                 varp             H5I_GROUP

# %%
# data <- t(readMM(file_path))
cell_type <- h5read(meta_path, name="obs/celltype")
sample_id <- h5read(meta_path, name="obs/sample_id")
pool_id <- h5read(meta_path, name="obs/pool_id")
time_point <- h5read(meta_path, name="obs/time_point")
treatment <- h5read(meta_path, name="obs/treatment")
gene <- h5read(meta_path, name="var/index")

cell_type <- get_categories(cell_type)
sample_id <- get_categories(sample_id)
pool_id <- get_categories(pool_id)
time_point <- get_categories(time_point)
treatment <- get_categories(treatment)

# %%
dim(data)
# Out:
# [1]  5000 12100

# %%
data_pool <- ComBat(data, pool_id)
data_sample <- ComBat(data, sample_id)
# Out:
# Found2batches
#
# Adjusting for0covariate(s) or covariate level(s)
#
# Standardizing Data across genes
#
# Fitting L/S model and finding priors
#
# Finding parametric adjustments
#
# Adjusting the Data
# Found 694 genes with uniform expression within a single batch (all zeros); these will not be adjusted for batch.
# Found30batches
#
# Adjusting for0covariate(s) or covariate level(s)
#
# Standardizing Data across genes
#
# Fitting L/S model and finding priors
#
# Finding parametric adjustments
#
# Adjusting the Data

# %%
# a metadata dataframe for the variables that we are interested in
meta = data.frame(sample_id=as.factor(sample_id), cell_type=as.factor(cell_type), time_point=as.factor(time_point), treatment=as.factor(treatment))
meta
# Out:
#       sample_id       cell_type time_point treatment
# 1     5245STDY7487301 P_FPP     D11        NONE
# 2     5245STDY7487301 NB        D11        NONE
# 3     5245STDY7487301 FPP       D11        NONE
# 4     5245STDY7487301 FPP       D11        NONE
# 5     5245STDY7487301 FPP       D11        NONE
# 6     5245STDY7487301 NB        D11        NONE
# 7     5245STDY7487301 P_FPP     D11        NONE
# 8     5245STDY7487301 FPP       D11        NONE
# 9     5245STDY7487301 FPP       D11        NONE
# 10    5245STDY7487301 FPP       D11        NONE
# 11    5245STDY7487301 NB        D11        NONE
# 12    5245STDY7487301 FPP       D11        NONE
# 13    5245STDY7487301 FPP       D11        NONE
# 14    5245STDY7487301 P_FPP     D11        NONE
# 15    5245STDY7487301 NB        D11        NONE
# 16    5245STDY7487301 FPP       D11        NONE
# 17    5245STDY7487301 FPP       D11        NONE
# 18    5245STDY7487301 FPP       D11        NONE
# 19    5245STDY7487301 NB        D11        NONE
# 20    5245STDY7487301 FPP       D11        NONE
# 21    5245STDY7487301 P_FPP     D11        NONE
# 22    5245STDY7487301 NB        D11        NONE
# 23    5245STDY7487301 FPP       D11        NONE
# 24    5245STDY7487301 FPP       D11        NONE
# 25    5245STDY7487301 NB        D11        NONE
# 26    5245STDY7487301 FPP       D11        NONE
# 27    5245STDY7487301 FPP       D11        NONE
# 28    5245STDY7487301 FPP       D11        NONE
# 29    5245STDY7487301 FPP       D11        NONE
# 30    5245STDY7487301 FPP       D11        NONE
# ⋮     ⋮               ⋮         ⋮          ⋮
# 12071 5245STDY7631346 Astro     D52        ROT
# 12072 5245STDY7631346 Astro     D52        ROT
# 12073 5245STDY7631346 Astro     D52        ROT
# 12074 5245STDY7631346 Epen1     D52        ROT
# 12075 5245STDY7631346 Epen1     D52        ROT
# 12076 5245STDY7631346 Astro     D52        ROT
# 12077 5245STDY7631346 Epen1     D52        ROT
# 12078 5245STDY7631346 Astro     D52        ROT
# 12079 5245STDY7631346 Astro     D52        ROT
# 12080 5245STDY7631346 Astro     D52        ROT
# 12081 5245STDY7631346 Astro     D52        ROT
# 12082 5245STDY7631346 Astro     D52        ROT
# 12083 5245STDY7631346 Astro     D52        ROT
# 12084 5245STDY7631346 FPP       D52        ROT
# 12085 5245STDY7631346 Astro     D52        ROT
# 12086 5245STDY7631346 P_FPP     D52        ROT
# 12087 5245STDY7631346 P_FPP     D52        ROT
# 12088 5245STDY7631346 Astro     D52        ROT
# 12089 5245STDY7631346 Epen1     D52        ROT
# 12090 5245STDY7631346 Astro     D52        ROT
# 12091 5245STDY7631346 P_FPP     D52        ROT
# 12092 5245STDY7631346 Astro     D52        ROT
# 12093 5245STDY7631346 FPP       D52        ROT
# 12094 5245STDY7631346 Astro     D52        ROT
# 12095 5245STDY7631346 Astro     D52        ROT
# 12096 5245STDY7631346 P_FPP     D52        ROT
# 12097 5245STDY7631346 DA        D52        ROT
# 12098 5245STDY7631346 Epen1     D52        ROT
# 12099 5245STDY7631346 Astro     D52        ROT
# 12100 5245STDY7631346 U_Neur1   D52        ROT

# %%
# pseudobulk metadata with 200 samples in total
bulk_meta = unique(meta)
bulk_meta
# Out:
#       sample_id       cell_type time_point treatment
# 1     5245STDY7487301 P_FPP     D11        NONE
# 2     5245STDY7487301 NB        D11        NONE
# 3     5245STDY7487301 FPP       D11        NONE
# 170   5245STDY7487302 FPP       D11        NONE
# 171   5245STDY7487302 NB        D11        NONE
# 172   5245STDY7487302 P_FPP     D11        NONE
# 414   5245STDY7520697 Epen1     D30        NONE
# 416   5245STDY7520697 FPP       D30        NONE
# 419   5245STDY7520697 P_FPP     D30        NONE
# 420   5245STDY7520697 U_Neur1   D30        NONE
# 422   5245STDY7520697 DA        D30        NONE
# 541   5245STDY7520697 U_Neur2   D30        NONE
# 561   5245STDY7520698 U_Neur1   D30        NONE
# 562   5245STDY7520698 Sert      D30        NONE
# 563   5245STDY7520698 FPP       D30        NONE
# 564   5245STDY7520698 Epen1     D30        NONE
# 571   5245STDY7520698 DA        D30        NONE
# 573   5245STDY7520698 P_FPP     D30        NONE
# 692   5245STDY7520699 Epen1     D30        NONE
# 693   5245STDY7520699 U_Neur1   D30        NONE
# 694   5245STDY7520699 FPP       D30        NONE
# 697   5245STDY7520699 DA        D30        NONE
# 704   5245STDY7520699 Sert      D30        NONE
# 708   5245STDY7520699 P_FPP     D30        NONE
# 820   5245STDY7520700 U_Neur1   D30        NONE
# 821   5245STDY7520700 Epen1     D30        NONE
# 822   5245STDY7520700 DA        D30        NONE
# 824   5245STDY7520700 FPP       D30        NONE
# 843   5245STDY7520700 P_FPP     D30        NONE
# 890   5245STDY7520700 Sert      D30        NONE
# ⋮     ⋮               ⋮         ⋮          ⋮
# 9609  5245STDY7631343 Epen2     D52        ROT
# 9636  5245STDY7631343 U_Neur3   D52        ROT
# 9692  5245STDY7631343 DA        D52        ROT
# 10117 5245STDY7631343 Sert      D52        ROT
# 10199 5245STDY7631344 FPP       D52        ROT
# 10200 5245STDY7631344 Astro     D52        ROT
# 10203 5245STDY7631344 P_FPP     D52        ROT
# 10206 5245STDY7631344 Epen1     D52        ROT
# 10210 5245STDY7631344 DA        D52        ROT
# 10239 5245STDY7631344 Epen2     D52        ROT
# 10287 5245STDY7631344 U_Neur3   D52        ROT
# 10314 5245STDY7631344 U_Neur1   D52        ROT
# 10773 5245STDY7631344 Sert      D52        ROT
# 10854 5245STDY7631345 Astro     D52        ROT
# 10857 5245STDY7631345 Epen1     D52        ROT
# 10862 5245STDY7631345 P_FPP     D52        ROT
# 10864 5245STDY7631345 U_Neur1   D52        ROT
# 10865 5245STDY7631345 DA        D52        ROT
# 10866 5245STDY7631345 FPP       D52        ROT
# 10904 5245STDY7631345 Epen2     D52        ROT
# 11063 5245STDY7631345 U_Neur3   D52        ROT
# 11275 5245STDY7631345 Sert      D52        ROT
# 11460 5245STDY7631346 U_Neur3   D52        ROT
# 11461 5245STDY7631346 FPP       D52        ROT
# 11462 5245STDY7631346 Epen1     D52        ROT
# 11464 5245STDY7631346 P_FPP     D52        ROT
# 11465 5245STDY7631346 DA        D52        ROT
# 11466 5245STDY7631346 Astro     D52        ROT
# 11511 5245STDY7631346 U_Neur1   D52        ROT
# 11523 5245STDY7631346 Epen2     D52        ROT

# %%
# Aggregate counts by groups defined by bulk samples
aggr_data <- aggregate(t(data_sample), by = list(meta$sample_id, meta$cell_type, meta$time_point, meta$treatment), FUN = sum)
aggr_data = t(aggr_data[,-c(1:4)])
aggr_data
# Out:
#       [,1]       [,2]        [,3]        [,4]        [,5]        [,6]
# V1    18.7885507  31.7364318  39.8777546  34.5825286  43.0598255  36.354372
# V2    13.4573108  22.4084006  38.5592479  36.8061990  35.8635571  36.194583
# V3     1.8851587   0.8075709   4.1472463   2.0886175   3.1223171   1.832711
# V4    41.3307017  56.2305484 100.7941410  81.5641225  93.4371982  95.459466
# V5    14.0110096  24.4332011  40.9817044  35.1724839  39.6657874  37.792582
# V6     2.7021494  13.8401131  17.5345529  15.5958096  18.2637731  11.464820
# V7     2.4384647   2.1900359   5.0568327   2.7248977   4.7992702   6.689583
# V8     6.4529028   9.6880563  14.3543898  12.4197850  15.7908536  14.125907
# V9     5.2871593   7.3973009  15.1491767  10.8193518  11.2874264  10.707829
# V10    9.9131861   9.9228470  22.6231525  18.7031714  16.9066033  16.455598
# V11    1.6657156   4.0961828   8.6879660   6.1110240   4.9390571   5.830890
# V12   17.2815990  25.0134164  47.2237620  43.9481819  54.1353121  41.790702
# V13   76.8888339 115.2991981 207.8721037 165.0056244 202.0973955 185.527176
# V4977  0.23167523   0.01914430  -0.012070871  0.97905073
# V4978 -0.02313893   0.68275346  -0.030545297  2.19709760
# V4979  0.02383471   0.01780087   0.004206317  0.01137126
# V4980  0.34589287   0.14040646  -0.038811861  1.50981343
# V4981  0.02282457   0.04130818   0.010404023  0.05965433
# V4982 -0.04494931   0.92274919  -0.023936271 -0.01681623
# V4983  0.38632998   0.54071380   0.808254060  1.09976247
# V4984  1.83991906   2.07070119  -0.267156469  0.33323528
# V4985  7.62912330  11.13707768   4.680259999 12.49916636
# V4986 11.54055824  15.10651349   4.923611391 17.54837860
# V4987 15.41469075  14.94824691   6.493990529 17.99540556
# V4988 14.11720546  15.00122249   5.907622411 17.07411665
# V4989 -0.04299369  -0.04408486  -0.012994932 -0.01541091
# V4990 10.47011971  11.62577404   2.988993812 12.43716877
# V4991 12.87623231  12.76680329   5.780487119 15.57768675
# V4992  8.58963159   9.57698573   1.217760710  9.62388588
# V4993  2.10363381   3.87026739   1.477461715  4.58091386
# V4994 13.19242859  14.75872011   5.663230449 16.07713294
# V4995  7.73491539   8.12482179   3.435302368  9.94809831
# V4996 13.13377405  14.58098457   5.920057454 14.94059378
# V4997  0.00000000   0.00000000   0.000000000  0.00000000
# V4998 -0.01476394  -0.02435851   0.001832331  0.01009523
# V4999  0.00000000   0.00000000   0.000000000  0.00000000
# V5000  0.49755030  -0.02709342  -0.002662802 -0.04025358

# %%
dim(data_pool)
# Out:
# [1]  5000 12100

# %%
aggr_data_pos = aggr_data - min(aggr_data)
# data_pos = data_pool - min(data_pool)
aggr_data_pos

# %%
# change bulk metadata to characters for future use
bulk_meta <- as.data.frame(lapply(bulk_meta, function(x) as.character(x)))
bulk_meta
# Out:
#     sample_id       cell_type time_point treatment
# 1   5245STDY7487301 P_FPP     D11        NONE
# 2   5245STDY7487301 NB        D11        NONE
# 3   5245STDY7487301 FPP       D11        NONE
# 4   5245STDY7487302 FPP       D11        NONE
# 5   5245STDY7487302 NB        D11        NONE
# 6   5245STDY7487302 P_FPP     D11        NONE
# 7   5245STDY7520697 Epen1     D30        NONE
# 8   5245STDY7520697 FPP       D30        NONE
# 9   5245STDY7520697 P_FPP     D30        NONE
# 10  5245STDY7520697 U_Neur1   D30        NONE
# 11  5245STDY7520697 DA        D30        NONE
# 12  5245STDY7520697 U_Neur2   D30        NONE
# 13  5245STDY7520698 U_Neur1   D30        NONE
# 14  5245STDY7520698 Sert      D30        NONE
# 15  5245STDY7520698 FPP       D30        NONE
# 16  5245STDY7520698 Epen1     D30        NONE
# 17  5245STDY7520698 DA        D30        NONE
# 18  5245STDY7520698 P_FPP     D30        NONE
# 19  5245STDY7520699 Epen1     D30        NONE
# 20  5245STDY7520699 U_Neur1   D30        NONE
# 21  5245STDY7520699 FPP       D30        NONE
# 22  5245STDY7520699 DA        D30        NONE
# 23  5245STDY7520699 Sert      D30        NONE
# 24  5245STDY7520699 P_FPP     D30        NONE
# 25  5245STDY7520700 U_Neur1   D30        NONE
# 26  5245STDY7520700 Epen1     D30        NONE
# 27  5245STDY7520700 DA        D30        NONE
# 28  5245STDY7520700 FPP       D30        NONE
# 29  5245STDY7520700 P_FPP     D30        NONE
# 30  5245STDY7520700 Sert      D30        NONE
# ⋮   ⋮               ⋮         ⋮          ⋮
# 171 5245STDY7631343 Epen2     D52        ROT
# 172 5245STDY7631343 U_Neur3   D52        ROT
# 173 5245STDY7631343 DA        D52        ROT
# 174 5245STDY7631343 Sert      D52        ROT
# 175 5245STDY7631344 FPP       D52        ROT
# 176 5245STDY7631344 Astro     D52        ROT
# 177 5245STDY7631344 P_FPP     D52        ROT
# 178 5245STDY7631344 Epen1     D52        ROT
# 179 5245STDY7631344 DA        D52        ROT
# 180 5245STDY7631344 Epen2     D52        ROT
# 181 5245STDY7631344 U_Neur3   D52        ROT
# 182 5245STDY7631344 U_Neur1   D52        ROT
# 183 5245STDY7631344 Sert      D52        ROT
# 184 5245STDY7631345 Astro     D52        ROT
# 185 5245STDY7631345 Epen1     D52        ROT
# 186 5245STDY7631345 P_FPP     D52        ROT
# 187 5245STDY7631345 U_Neur1   D52        ROT
# 188 5245STDY7631345 DA        D52        ROT
# 189 5245STDY7631345 FPP       D52        ROT
# 190 5245STDY7631345 Epen2     D52        ROT
# 191 5245STDY7631345 U_Neur3   D52        ROT
# 192 5245STDY7631345 Sert      D52        ROT
# 193 5245STDY7631346 U_Neur3   D52        ROT
# 194 5245STDY7631346 FPP       D52        ROT
# 195 5245STDY7631346 Epen1     D52        ROT
# 196 5245STDY7631346 P_FPP     D52        ROT
# 197 5245STDY7631346 DA        D52        ROT
# 198 5245STDY7631346 Astro     D52        ROT
# 199 5245STDY7631346 U_Neur1   D52        ROT
# 200 5245STDY7631346 Epen2     D52        ROT

# %%
# aggregated data
data_DA <- aggr_data_pos[, which(bulk_meta$time_point=="D52" & bulk_meta$cell_type=="DA")]
meta_DA <- bulk_meta[which(bulk_meta$time_point=="D52" & bulk_meta$cell_type=="DA"),]$treatment
dim(data_DA)
data_nonDA <- aggr_data_pos[, which(bulk_meta$time_point=="D52" & bulk_meta$cell_type!="DA")]
meta_nonDA <- bulk_meta[which(bulk_meta$time_point=="D52" & bulk_meta$cell_type!="DA"),]$treatment
dim(data_nonDA)
# Out:
# [1] 5000   16
# [1] 5000  113

# %%
# single cell data
data_DA <- data_pos[,which(time_point=="D52" & cell_type=="DA")]
meta_DA <- treatment[which(time_point=="D52" & cell_type=="DA")]
dim(data_DA)
data_nonDA <- data_pos[,which(time_point=="D52" & cell_type!="DA")]
meta_nonDA <- treatment[which(time_point=="D52" & cell_type!="DA")]
dim(data_nonDA)
# Out:
# [1] 5000  434

# %%
res_DA <- DE_limmavoom(counts=data_DA, group=as.factor(meta_DA), contrfml = "groupROT-groupNONE", 
                    cutoff=1.0, thres_type="adjp",
                    p_thres=0.05, lfc_thres=1.0, adj_method = "BH")
# Out:
# [1] "5000 out of 5000 genes left after filtering low-expressed genes"
#            Contrasts
# Levels      groupROT-groupNONE
#   groupNONE                 -1
#   groupROT                   1

# %%
res_nonDA <- DE_limmavoom(counts=data_nonDA, group=as.factor(meta_nonDA), contrfml = "groupROT-groupNONE", 
                    cutoff=1.0, thres_type="adjp",
                    p_thres=0.05, lfc_thres=1.0, adj_method = "BH")
# Out:
# [1] "5000 out of 5000 genes left after filtering low-expressed genes"
#            Contrasts
# Levels      groupROT-groupNONE
#   groupNONE                 -1
#   groupROT                   1

# %%
res <- res_nonDA

# %%
toptable <- res$toptable
toptable$color <- ifelse(toptable$adj.P.Val < 0.05, ifelse(toptable$logFC < 0, "red", "blue"), "grey")
p <- ggplot(data = toptable, aes(x = logFC, y = -log10(adj.P.Val), col = color)) +
    geom_vline(xintercept = c(-0.6, 0.6), col = "grey", linetype = 'dashed') +
    geom_hline(yintercept = -log10(0.05), col = "grey", linetype = 'dashed') +
    geom_point(size = 2) +
    scale_color_manual(values = c("red", "grey", "blue"), 
                       labels = c("Upregulated", "Not significant", "Downregulated")) +
    coord_cartesian(ylim = c(0, 25), xlim = c(-0.2, 0.2)) +
    labs(color = 'Significance',
         x = expression("log"[2]*" Fold Change"),
         y = expression("-log"[10]*" Adjusted p-value")) +
    ggtitle('Volcano plot (DESeq2)') +
    theme_minimal()
p
# Out:
# plot without title

# %%
res$volcano_plot
# Out:
# plot without title

# %%
res$toptable
# Out:
#       logFC         AveExpr  t             P.Value      adj.P.Val    B
# V2987 -0.18084387   7.417766 -5.946235     2.952635e-08 0.0001476317 8.669240
# V4933 -0.18018669   7.363738 -5.774177     6.567222e-08 0.0001641806 7.897263
# V614  -0.14006144   7.331662 -5.263000     6.567080e-07 0.0008716610 5.756684
# V1877 -0.16074460   7.404232 -5.211282     8.236491e-07 0.0008716610 5.558870
# V370  -0.10628053   7.400231 -5.198300     8.716610e-07 0.0008716610 5.504416
# V2838 -0.09053297   7.320583 -5.148712     1.081491e-06 0.0009012428 5.293058
# V3913 -0.10439389   7.315017 -4.926349     2.803710e-06 0.0017926176 4.417980
# V862  -0.13002193   7.362657 -4.892148     3.239079e-06 0.0017926176 4.289092
# V1909 -0.27880801   7.362213 -4.873642     3.501340e-06 0.0017926176 4.216574
# V3793 -0.09353950   7.387348 -4.868005     3.585235e-06 0.0017926176 4.195765
# V2681 -0.16641028   7.364552 -4.789695     4.973450e-06 0.0022606591 3.894134
# V1127  0.20491665   7.338728  4.741283     6.079108e-06 0.0025329615 3.702418
# V4752 -0.19724448   7.473355 -4.683316     7.718355e-06 0.0029685980 3.477577
# V2755 -0.15269586   7.379625 -4.639267     9.242632e-06 0.0033009401 3.321660
# V3256 -0.08613849   7.360371 -4.612105     1.032367e-05 0.0033042142 3.224344
# V1961  0.10175766   7.328045  4.588739     1.135065e-05 0.0033042142 3.136568
# V1138 -0.17929339   7.357453 -4.587015     1.143019e-05 0.0033042142 3.126356
# V3560 -8.823741e-05 7.275370 -3.389332e-03 0.9973015    0.9990999    -6.065935
# V49   -6.954425e-05 7.303596 -3.127666e-03 0.9975099    0.9991084    -6.083206
# V4095  4.371654e-04 8.822188  2.726788e-03 0.9978290    0.9991779    -4.892866
# V959   4.872604e-05 7.587150  2.538527e-03 0.9979789    0.9991779    -6.338575
# V2765 -3.865562e-05 7.335977 -2.188471e-03 0.9982576    0.9992569    -6.109696
# V4583  4.644990e-05 7.614066  1.893986e-03 0.9984921    0.9992915    -6.326189
# V2964 -4.375266e-05 7.264761 -1.587048e-03 0.9987364    0.9993360    -6.059024
# V4698 -2.405235e-05 7.382549 -1.187418e-03 0.9990546    0.9994401    -6.144689
# V4822  2.746900e-05 7.253624  9.543063e-04 0.9992402    0.9994401    -6.053395
# V3668  8.627725e-07 7.559434  4.286001e-05 0.9999659    0.9999659    -6.356327
#       genes
# V2987 V2987
# V4933 V4933
# V614  V614
# V1877 V1877
# V370  V370
# V2838 V2838
# V3913 V3913
# V862  V862
# V1909 V1909
# V3793 V3793
# V2681 V2681
# V1127 V1127
# V4752 V4752
# V2755 V2755
# V3256 V3256
# V1961 V1961
# V1138 V1138
# V4828 V4828
# V973  V973
# V4732 V4732
# V749  V749
# V993  V993
# V531  V531
# V4781 V4781
# V4825 V4825
# V1589 V1589
# V2916 V2916
# V774  V774
# V2068 V2068
# V4883 V4883
# ⋮     ⋮
# V692  V692
# V177  V177
# V505  V505
# V4116 V4116
# V258  V258
# V533  V533
# V3304 V3304
# V3724 V3724
# V1420 V1420
# V4498 V4498
# V3918 V3918
# V4003 V4003
# V846  V846
# V2107 V2107
# V2840 V2840
# V2109 V2109
# V4764 V4764
# V4087 V4087
# V2020 V2020
# V785  V785
# V3560 V3560
# V49   V49
# V4095 V4095
# V959  V959
# V2765 V2765
# V4583 V4583
# V2964 V2964
# V4698 V4698
# V4822 V4822
# V3668 V3668

# %%
hist(res$toptable$P.Value, breaks=100, xlim=c(0.0, 1.0), ylim=c(0, 400))
hist(res$toptable$adj.P.Val, breaks=100, xlim=c(0.0, 1.0), ylim=c(0, 400))
# Out:
# Plot with title “Histogram of res$toptable$P.Value”
# Plot with title “Histogram of res$toptable$adj.P.Val”

# %%
sum(res$toptable$adj.P.Val < 0.05)
# Out:
# [1] 175

# %%
# complete.results_Cheung <- na.omit(results_Cheung)
res_fdr <- fdrtool(res$toptable$t, statistic = "normal", plot = TRUE)

hist(res$toptable$t, breaks=20)
hist(res_fdr$pval, breaks=20)
hist(res_fdr$lfdr, breaks=20)
hist(res_fdr$qval, breaks=20)

# %%
res$predicted <- ifelse(1:nrow(sim.data$counts) %in% res$de_genes, "DE", "Not DE")
res$actual <- ifelse(1:nrow(sim.data$counts) %in% sim.data$DEid, "DE", "Not DE")
confusion_matrix <- table(res$actual, res$predicted)
sum(res$predicted=="DE")
sum(res$actual=="DE")

metrics <- calculate_metrics(confusion_matrix)
metrics
